# %% [markdown]
# # Video Game Analysis
# Author: Rob Kelley
# Date: 2/14/22
# Version: 1.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('vgsales.csv')

# %%
df.sample(10)
# Out:
#         Rank                                               Name Platform  \
# 10539  10541              Yggdra Union: We'll Never Fight Alone      PSP
# 9166    9168                      NCAA Basketball Final Four 97       PS
# 12542  12544           Little League World Series Baseball 2008       DS
# 9348    9350  Hisshou Pachinko*Pachi-Slot Kouryaku Series Vo...      PS2
# 2518    2520                                 DmC: Devil May Cry      PS3
# 16448  16451                        Assassin's Creed Chronicles     XOne
# 13444  13446                                     Nanda's Island       DS
# 1592    1594                                              Black      PS2
# 4556    4558                            Midway Arcade Treasures       XB
# 16427  16430                                       Virtua Quest       GC
#
#          Year         Genre        Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 10539  2008.0  Role-Playing            Sting      0.05      0.00      0.04
# ...

# %%
df.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
df.Year = list(map(lambda x: str(x)[0:4], df.Year))

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df.rename(columns={'Global_Sales':'Global_Sales_M'},inplace=True)

# %%
df.rename(columns={'EU_Sales':'EU_Sales_M','JP_Sales':'JP_Sales_M','Other_Sales':'Other_Sales_M'},inplace=True)

# %%
df.dtypes
# Out:
# Rank                int64
# Name               object
# Platform           object
# Year               object
# Genre              object
# Publisher          object
# NA_Sales          float64
# EU_Sales_M        float64
# JP_Sales_M        float64
# Other_Sales_M     float64
# Global_Sales_M    float64
# dtype: object

# %%
#df.drop('Rank', inplace=True, axis=1)

# %%
df.sample(10)
# Out:
#         Rank                         Name Platform  Year         Genre  \
# 12185  12187    Brain Quest: Grades 3 & 4       DS  2008          Misc
# 10531  10533  X-Men: Children of the Atom       PS  1998      Fighting
# 14646  14649                   Botanicula       PC  2012     Adventure
# 11187  11189            Rollcage Stage II       PS  2000        Racing
# 4930    4932       All-Star Baseball 2000      N64  1999        Sports
# 8562    8564             NASCAR Heat 2002      GBA  2002        Racing
# 14436  14439                 Gloria Union      PSP  2011  Role-Playing
# 2938    2940  Fire Emblem: Monsh? no Nazo     SNES  1994  Role-Playing
# 5468    5470                   The Sims 2       GC  2005    Simulation
# 11        12                Mario Kart DS       DS  2005        Racing
#
#                          Publisher  NA_Sales  EU_Sales_M  JP_Sales_M  \
# 12185              Electronic Arts      0.06        0.00        0.00
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales_M', 'JP_Sales_M', 'Other_Sales_M', 'Global_Sales_M', 'Rank'],
#       dtype='object')

# %%
df.columns = ['Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
       'EU_Sales_M', 'JP_Sales_M', 'Other_Sales_M', 'Global_Sales_M','Rank']

# %%
df.head()
# Out:
#    Name                  Platform Year Genre     Publisher  NA_Sales  \
# 0     1                Wii Sports  Wii  2006        Sports  Nintendo
# 1     2         Super Mario Bros.  NES  1985      Platform  Nintendo
# 2     3            Mario Kart Wii  Wii  2008        Racing  Nintendo
# 3     4         Wii Sports Resort  Wii  2009        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue   GB  1996  Role-Playing  Nintendo
#
#    EU_Sales_M  JP_Sales_M  Other_Sales_M  Global_Sales_M   Rank
# 0       41.49       29.02           3.77            8.46  82.74
# 1       29.08        3.58           6.81            0.77  40.24
# 2       15.85       12.88           3.79            3.31  35.82
# 3       15.75       11.01           3.28            2.96  33.00
# 4       11.27        8.89          10.22            1.00  31.37
